# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd

# %%
state_cases = pd.read_csv("/Users/CharlesFederici/corona_python/data/by_state.csv")
states = pd.read_csv("/Users/CharlesFederici/corona_python/admin/states.csv")
states = states.State.tolist()

metrics = ['confirmed','deaths','recovered',
           'incremental_confirmed','incremental_deaths','incremental_recovered']

# %%
state_cases
# Out:
#       Unnamed: 0 province_state country_region  confirmed  deaths  recovered  \
# 0            490     Washington             US      366.0    29.0        1.0
# 1            494       New York             US      220.0     0.0        0.0
# 2            497     California             US      177.0     3.0        2.0
# 3            501  Massachusetts             US       95.0     0.0        1.0
# 4            523       Colorado             US       34.0     0.0        0.0
# ...          ...            ...            ...        ...     ...        ...
# 4809       24573        Wyoming             US      960.0    17.0        0.0
# 4810       24574        Wyoming             US      970.0    17.0        0.0
# 4811       24575        Wyoming             US      980.0    18.0        0.0
# 4812       24576        Wyoming             US     1009.0    18.0        0.0
# 4813       24577        Wyoming             US     1027.0    18.0        0.0
#
#      report_date   latitude   longitude  confirmed_pd  deaths_pd  \
# 0     2020-03-11  47.400900 -121.490500         267.0       23.0
# 1     2020-03-11  42.165700  -74.948100         173.0        0.0
# 2     2020-03-11  36.116200 -119.681600         144.0        2.0
# 3     2020-03-11  42.230200  -71.530100          92.0        0.0
# 4     2020-03-11  39.059800 -105.311100          15.0        0.0
# ...          ...        ...         ...           ...        ...
# 4809  2020-06-08  43.086886 -107.153242         947.0       17.0
# 4810  2020-06-09  43.086886 -107.153242         960.0       17.0
# 4811  2020-06-10  43.086886 -107.153242         970.0       17.0
# 4812  2020-06-11  43.086886 -107.153242         980.0       18.0
# 4813  2020-06-12  43.086886 -107.153242        1009.0       18.0
#
#       recovered_pd  incremental_confirmed  incremental_deaths  \
# 0              1.0                   99.0                 6.0
# 1              0.0                   47.0                 0.0
# 2              2.0                   33.0                 1.0
# 3              1.0                    3.0                 0.0
# 4              0.0                   19.0                 0.0
# ...            ...                    ...                 ...
# 4809           0.0                   13.0                 0.0
# 4810           0.0                   10.0                 0.0
# 4811           0.0                   10.0                 1.0
# 4812           0.0                   29.0                 0.0
# 4813           0.0                   18.0                 0.0
#
#       incremental_recovered  keep
# 0                       0.0     1
# 1                       0.0     1
# 2                       0.0     1
# 3                       0.0     1
# 4                       0.0     1
# ...                     ...   ...
# 4809                    0.0     1
# 4810                    0.0     1
# 4811                    0.0     1
# 4812                    0.0     1
# 4813                    0.0     1
#
# [4814 rows x 16 columns]
